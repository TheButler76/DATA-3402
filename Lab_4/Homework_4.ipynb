# %% [markdown]
# # Homework 4-Basic Data Manipulation and Visualization
#
#
#
# # **Assignment Submission Guidelines**
#
#
# Please follow the guidelines below for submitting your assignment:
#
# 1. **Submission Deadline:**
#    - All assignments must be submitted **no later than 11:59 PM Next Monday (10/20) Midnight**.
#    - Late submissions will not be accepted unless prior arrangements have been made by the instructor.
#
# 2. **Submission Platform:**
#    - Submit your assignment through **Canvas**. Ensure that you upload the files to the correct assignment link.
#
# 3. **Required Files:**
#    - **Jupyter Notebook file (.ipynb):** Submit the Jupyter Notebook file you used to complete the assignment. The file should contain your well-commented code.
#    - **PDF Version (.pdf file):** Additionally, submit a PDF version of your Python code. This can be a printout or export of your script, showing all the code with any necessary explanations or output results included.
#
# 4. **File Naming Convention:**
#    - Please name your files as follows: `Lastname_Firstname_AssignmentName`
#    - Example: `Alex_John_Homework4.ipynb` and `Alex_Johb_Homework4.pdf`
#
# 5. **Technical Issues:**
#    - If you encounter any technical issues with Canvas or your submission, please contact the TAs immediately **before the deadline** to avoid penalties.

# %% [markdown]
# ## 1. Load and Inspect Data (10 Points)
#
#
#
# Load the 2012_Workplace_Fatalities_by_State.csv file into a Pandas DataFrame.
#
# Display the first 50 rows of data in the first column.
#
# Replace all missing values with 0.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data=pd.read_csv('2012_Workplace_Fatalities_by_State.csv')

# %%
# This block shows us the counts of NaN data in each column. Lucky for us, they are all of the same length.
data.isna()
data_na = data.isna() == 'False'
data_na.count()
# Out:
# State                                   54
# Number of Fatalities, 2012              54
# Rate of Fatalities, 2012                54
# State Rank, Fatalities 2012             54
# Number of Injuries/Illnesses 2012       54
# Injuries/Illnesses 2012 Rate            54
# Penalties FY 2013 (Average $)           54
# Penalties FY 2013 (Rank)                54
# Inspectors                              54
# Years to Inspect Each Workplace Once    54
# State or Federal Program                54
# dtype: int64

# %%
# This block fills the NaN values with zeros
data.fillna(0, inplace=True)
data.head(50)
# Out:
#                                                 State  \
# 0   South Carolina\n(33.99882060100049, -81.045367...
# 1   West Virginia\n(38.665511497000466, -80.712639...
# 2   Massachusetts\n(42.27687306500047, -72.0826898...
# 3   Tennessee\n(35.680943063000484, -85.7744864219...
# 4   Oklahoma\n(35.472034350000456, -97.52106845499...
# 5   Illinois\n(40.48501278700047, -88.99770813999965)
# 6   Nebraska\n(41.64104043900045, -99.36571864599966)
# 7   Delaware\n(39.00883351400046, -75.57773943699965)
# 8    Hawaii\n(21.30485166200043, -157.85774691599974)
# 9      Iowa\n(42.469404401000475, -93.81648936699969)
# 10  Arizona\n(34.865973091000455, -111.76380949799...
# 11  Florida\n(28.932042899000464, -81.92895558499964)
# 12  Virginia\n(37.54268075100049, -78.45788924199968)
# 13  Missouri\n(38.63579372300046, -92.56629737199967)
# 14  Michigan\n(44.66131575600048, -84.71438724399968)
# 15   Indiana\n(39.76691364600049, -86.14995579899966)
# 16  North Carolina\n(35.46622388600048, -79.159249...
# 17  New Hampshire\n(43.6559537330005, -71.50035726...
# 18  New Mexico\n(34.52088247800049, -106.240577688...
# 19  Pennsylvania\n(40.79373106100047, -77.86069775...
# 20  South Dakota\n(44.35313342000046, -100.3735281...
#     Penalties FY 2013 (Rank)  Inspectors  \
# 0                       49.0        24.0
# 1                       27.0         7.0
# 2                       21.0        33.0
# 3                       45.0        30.0
# 4                       24.0        19.0
# 5                       23.0        74.0
# 6                        5.0         9.0
# 7                        6.0         5.0
# 8                       39.0        20.0
# 9                       43.0        26.0
# 10                      40.0        30.0
# 11                      25.0        60.0
# 12                      46.0        48.0
# 13                      20.0        26.0
# 14                      48.0        63.0
# 15                      34.0        39.0
# 16                      38.0       104.0
# 17                       8.0         7.0
# 18                      37.0         9.0
# 19                      22.0        57.0
# 20                       7.0         0.0
# 21                      17.0       105.0
# 22                      35.0        22.0
# 23                      14.0         8.0
# 24                      18.0         7.0
# 25                      36.0         9.0
# 26                       4.0         9.0
# 27                      13.0        44.0
# 28                       2.0        39.0
# 29                      47.0        48.0
# 30                      26.0        24.0
# 31                      30.0        24.0
# 32                      50.0        75.0
# 33                      31.0        28.0
# 34                      11.0        53.0
# 35                      28.0         9.0
# 36                      44.0        58.0
# 37                      19.0        16.0
# 38                      33.0         9.0
# 39                      42.0       111.0
# 40                       9.0        36.0
# 41                      32.0        14.0
# 42                      29.0        16.0
# 43                      15.0        49.0
# 44                      16.0         7.0
# 45                      41.0        11.0
# 46                      12.0        67.0
# 47                       3.0         8.0
# 48                      10.0        98.0
# 49                       1.0       216.0
#
#     Years to Inspect Each Workplace Once State or Federal Program
# 0                                  111.0                    State
# 1                                  173.0                  Federal
# 2                                  123.0                  Federal
# 3                                   82.0                    State
# 4                                  131.0                  Federal
# 5                                  137.0                  Federal
# 6                                  128.0                  Federal
# 7                                  175.0                  Federal
# 8                                   79.0                    State
# 9                                   98.0                    State
# 10                                 126.0                    State
# 11                                 238.0                  Federal
# 12                                  82.0                    State
# 13                                 118.0                  Federal
# 14                                  45.0                    State
# 15                                 104.0                    State
# 16                                  60.0                    State
# 17                                 119.0                  Federal
# 18                                 191.0                    State
# 19                                 125.0                  Federal
# 20                                 521.0                  Federal
# 21                                 184.0                  Federal
# 22                                  81.0                    State
# 23                                  80.0                  Federal
# 24                                 135.0                  Federal
# 25                                  68.0                    State
# 26                                 237.0                  Federal
# 27                                  49.0                    State
# 28                                 124.0                    State
# 29                                 108.0                    State
# 30                                  94.0                  Federal
# 31                                 107.0                  Federal
# 32                                  31.0                    State
# 33                                 122.0                  Federal
# 34                                 112.0                  Federal
# 35                                 101.0                    State
# 36                                  57.0                    State
# 37                                 110.0                  Federal
# 38                                 108.0                  Federal
# 39                                  50.0                    State
# 40                                 104.0                  Federal
# 41                                 112.0                  Federal
# 42                                 206.0                  Federal
# 43                                 138.0                  Federal
# 44                                 103.0                  Federal
# 45                                  58.0                    State
# 46                                 123.0                  Federal
# 47                                 111.0                  Federal
# 48                                 136.0                  Federal
# 49                                 179.0                    State

# %% [markdown]
# ##  2. Clean up the state names (10 Points)
#
# The first column ('State') that contains both U.S. state names and their coordinates in a messy format. Please remove the coordinates between the state names. Add two columns of longitude and latitude to the data.

# %%
State_data = data['State']
lat=list()
long=list()
for i, key in State_data.items():
    if isinstance(key, int):
        continue
    try:
        print("Row: ", i,  "Replace the row of the State col with `key_str`.")
        key_split = key.splitlines()
        key_str = str(key_split[0])
        # replace ===========================================================================================
        data['State'].replace(data['State'].iloc[i], key_str, inplace=True)
        # replace ===========================================================================================
        print(key_split)
        coordinates = key_split[1].strip("()")
        lat_str,long_str = coordinates.split(",")
        lat.append(float(lat_str))
        long.append(float(long_str))
        print("================")
    except Exception as e:
        print(" Error: ", e, "because there are some values that are zero.")
# Out:
# Row:  0 Replace the row of the State col with `key_str`.
# ['South Carolina', '(33.99882060100049, -81.04536765699964)']
# ================
# Row:  1 Replace the row of the State col with `key_str`.
# ['West Virginia', '(38.665511497000466, -80.71263935099967)']
# ================
# Row:  2 Replace the row of the State col with `key_str`.
# ['Massachusetts', '(42.27687306500047, -72.08268985899963)']
# ================
# Row:  3 Replace the row of the State col with `key_str`.
# ['Tennessee', '(35.680943063000484, -85.77448642199965)']
# ================
# Row:  4 Replace the row of the State col with `key_str`.
# ['Oklahoma', '(35.472034350000456, -97.52106845499969)']
# ================
# Row:  5 Replace the row of the State col with `key_str`.
# ['Illinois', '(40.48501278700047, -88.99770813999965)']
# ================
# Row:  6 Replace the row of the State col with `key_str`.
# ['Nebraska', '(41.64104043900045, -99.36571864599966)']
# ================
# Row:  7 Replace the row of the State col with `key_str`.
# ['Delaware', '(39.00883351400046, -75.57773943699965)']
# ================
# Row:  8 Replace the row of the State col with `key_str`.
# ['Hawaii', '(21.30485166200043, -157.85774691599974)']
# ================
# Row:  9 Replace the row of the State col with `key_str`.
# ['Iowa', '(42.469404401000475, -93.81648936699969)']
# ================
# Row:  10 Replace the row of the State col with `key_str`.
# ['Arizona', '(34.865973091000455, -111.76380949799972)']
# ================
# Row:  11 Replace the row of the State col with `key_str`.
# ['Florida', '(28.932042899000464, -81.92895558499964)']
# ================
# Row:  12 Replace the row of the State col with `key_str`.
# ['Virginia', '(37.54268075100049, -78.45788924199968)']
# ================
# Row:  13 Replace the row of the State col with `key_str`.
# ['Missouri', '(38.63579372300046, -92.56629737199967)']
# ================
# Row:  14 Replace the row of the State col with `key_str`.
# ['Michigan', '(44.66131575600048, -84.71438724399968)']
# ================
# Row:  15 Replace the row of the State col with `key_str`.
# ['Indiana', '(39.76691364600049, -86.14995579899966)']
# ================
# Row:  16 Replace the row of the State col with `key_str`.
# ['North Carolina', '(35.46622388600048, -79.15924924699965)']
# ================
# Row:  17 Replace the row of the State col with `key_str`.
# ['New Hampshire', '(43.6559537330005, -71.50035726399966)']
# ================
# Row:  18 Replace the row of the State col with `key_str`.
# ['New Mexico', '(34.52088247800049, -106.24057768899968)']
# ================
# Row:  19 Replace the row of the State col with `key_str`.
# ['Pennsylvania', '(40.79373106100047, -77.86069775999965)']
# ================
# Row:  20 Replace the row of the State col with `key_str`.
# ['South Dakota', '(44.35313342000046, -100.37352811899967)']
# ================
# Row:  21 Replace the row of the State col with `key_str`.
# ['New York', '(42.82700023900048, -75.54396639699968)']
# ================
# Row:  22 Replace the row of the State col with `key_str`.
# ['Utah', '(39.36070374600047, -111.5871285339997)']
# ================
# Row:  23 Replace the row of the State col with `key_str`.
# ['Maine', '(45.254228663000504, -68.98502952999962)']
# ================
# Row:  24 Replace the row of the State col with `key_str`.
# ['Montana', '(47.066526051000494, -109.42441687999968)']
# ================
# Row:  25 Replace the row of the State col with `key_str`.
# ['Vermont', '(43.62538292400046, -72.51763944499965)']
# ================
# Row:  26 Replace the row of the State col with `key_str`.
# ['Arkansas', '(34.748651751000466, -92.27448794899965)']
# ================
# Row:  27 Replace the row of the State col with `key_str`.
# ['Nevada', '(39.49324126500045, -117.07183978499972)']
# ================
# Row:  28 Replace the row of the State col with `key_str`.
# ['Kentucky', '(37.645973909000475, -84.77496612599964)']
# ================
# Row:  29 Replace the row of the State col with `key_str`.
# ['Maryland', '(39.2905806980005, -76.60925970899967)']
# ================
# Row:  30 Replace the row of the State col with `key_str`.
# ['Alabama', '(32.84057327200048, -86.63185803899967)']
# ================
# Row:  31 Replace the row of the State col with `key_str`.
# ['Connecticut', '(41.56266394200048, -72.64983753699966)']
# ================
# Row:  32 Replace the row of the State col with `key_str`.
# ['Oregon', '(44.567446178000466, -120.15502977999972)']
# ================
# Row:  33 Replace the row of the State col with `key_str`.
# ['Colorado', '(38.84384047000049, -106.13360888799969)']
# ================
# Row:  34 Replace the row of the State col with `key_str`.
# ['Ohio', '(40.06021029700048, -82.40425685299965)']
# ================
# Row:  35 Replace the row of the State col with `key_str`.
# ['Wyoming', '(43.23554147100049, -108.10982744299969)']
# ================
# Row:  36 Replace the row of the State col with `key_str`.
# ['Minnesota', '(46.35564867700049, -94.79419697699967)']
# ================
# Row:  37 Replace the row of the State col with `key_str`.
# ['Kansas', '(38.34774033400049, -98.20077655499966)']
# ================
# Row:  38 Replace the row of the State col with `key_str`.
# ['Idaho', '(43.682630058000484, -114.3637261449997)']
# ================
# Row:  39 Replace the row of the State col with `key_str`.
# ['Washington', '(47.522287905000496, -120.47002746299972)']
# ================
# Row:  40 Replace the row of the State col with `key_str`.
# ['Wisconsin', '(44.3931903350005, -89.81636715299965)']
# ================
# Row:  41 Replace the row of the State col with `key_str`.
# ['Mississippi', '(32.74551123200047, -89.53802764499966)']
# ================
# Row:  42 Replace the row of the State col with `key_str`.
# ['Louisiana', '(31.312662564000448, -92.44567554599968)']
# ================
# Row:  43 Replace the row of the State col with `key_str`.
# ['Georgia', '(32.83968004200045, -83.62757601199968)']
# ================
# Row:  44 Replace the row of the State col with `key_str`.
# ['Rhode Island', '(41.70828281900049, -71.52246918099962)']
# ================
# Row:  45 Replace the row of the State col with `key_str`.
# ['Alaska', '(64.84507923900048, -147.72205669099972)']
# ================
# Row:  46 Replace the row of the State col with `key_str`.
# ['New Jersey', '(40.1305700530005, -74.27368565099965)']
# ================
# Row:  47 Replace the row of the State col with `key_str`.
# ['North Dakota', '(47.47531738700047, -100.11842599699969)']
# ================
# Row:  48 Replace the row of the State col with `key_str`.
# ['Texas', '(31.827243635000457, -99.4267664729997)']
# ================
# Row:  49 Replace the row of the State col with `key_str`.
# ['California', '(37.638640488000476, -120.99999889499969)']
# ================
# Row:  53 Replace the row of the State col with `key_str`.
# ['Total or National, Average']
#  Error:  list index out of range because there are some values that are zero.

# %%
data
# Out:
#                          State  Number of Fatalities, 2012  \
# 0               South Carolina                        63.0
# 1                West Virginia                        49.0
# 2                Massachusetts                        44.0
# 3                    Tennessee                       101.0
# 4                     Oklahoma                        97.0
# 5                     Illinois                       146.0
# 6                     Nebraska                        48.0
# 7                     Delaware                        14.0
# 8                       Hawaii                        20.0
# 9                         Iowa                        97.0
# 10                     Arizona                        60.0
# 11                     Florida                       218.0
# 12                    Virginia                       149.0
# 13                    Missouri                        88.0
# 14                    Michigan                       137.0
# 15                     Indiana                       115.0
# 16              North Carolina                       146.0
# 17               New Hampshire                        14.0
# 18                  New Mexico                        39.0
# 19                Pennsylvania                       194.0
# 20                South Dakota                        31.0
# 21                    New York                       202.0
# 22                        Utah                        39.0
# 23                       Maine                        19.0
# 24                     Montana                        34.0
# 25                     Vermont                        11.0
# 26                    Arkansas                        63.0
# 27                      Nevada                        42.0
# 28                    Kentucky                        91.0
# 29                    Maryland                        72.0
# 30                     Alabama                        84.0
# 31                 Connecticut                        36.0
# 32                      Oregon                        43.0
# 33                    Colorado                        82.0
# 34                        Ohio                       161.0
# 35                     Wyoming                        35.0
# 36                   Minnesota                        70.0
# 37                      Kansas                        76.0
# 38                       Idaho                        19.0
# 39                  Washington                        67.0
# 40                   Wisconsin                       114.0
# 41                 Mississippi                        63.0
# 42                   Louisiana                       116.0
# 43                     Georgia                       101.0
# 44                Rhode Island                         8.0
# 45                      Alaska                        31.0
# 46                  New Jersey                        92.0
# 47                North Dakota                        65.0
# 48                       Texas                       536.0
# 49                  California                       375.0
# 50                           0                         0.0
# 51                           0                         0.0
# 52                           0                         0.0
# 53  Total or National, Average                      4628.0
#
#     Rate of Fatalities, 2012  State Rank, Fatalities 2012  \
# 0                        3.5                         25.0
# 1                        6.9                         46.0
# 2                        1.4                          1.0
# 3                        3.8                         30.0
# 4                        6.1                         42.0
# 5                        2.5                         10.0
# 6                        5.2                         38.0
# 7                        3.1                         18.0
# 8                        3.4                         22.0
# 9                        6.6                         44.0
# 10                       2.3                          6.0
# 11                       2.7                         15.0
# 12                       3.8                         30.0
# 13                       3.3                         21.0
# 14                       3.4                         22.0
# 15                       4.2                         33.0
# 16                       3.5                         25.0
# 17                       2.2                          4.0
# 18                       4.8                         35.0
# 19                       3.4                         22.0
# 20                       6.7                         45.0
# 21                       2.4                          8.0
# 22                       3.0                         17.0
# 23                       3.2                         20.0
# 24                       7.3                         47.0
# 25                       3.5                         25.0
# 26                       5.4                         39.0
# 27                       3.6                         29.0
# 28                       4.9                         37.0
# 29                       2.6                         12.0
# 30                       4.3                         34.0
# 31                       2.1                          3.0
# 32                       2.6                         12.0
# 33                       3.5                         25.0
# 34                       3.1                         18.0
# 35                      12.2                         49.0
# 36                       2.6                         12.0
# 37                       5.7                         41.0
# 38                       2.7                         15.0
# 39                       2.2                          4.0
# 40                       4.0                         32.0
# 41                       5.5                         40.0
# 42                       6.4                         43.0
# 43                       2.5                         10.0
# 44                       1.7                          2.0
# 45                       8.9                         48.0
# 46                       2.4                          8.0
# 47                      17.7                         50.0
# 32                          363.0                      50.0        75.0
# 33                         1649.0                      31.0        28.0
# 34                         2156.0                      11.0        53.0
# 35                         1777.0                      28.0         9.0
# 36                          768.0                      44.0        58.0
# 37                         1971.0                      19.0        16.0
# 38                         1449.0                      33.0         9.0
# 39                          791.0                      42.0       111.0
# 40                         2207.0                       9.0        36.0
# 41                         1515.0                      32.0        14.0
# 42                         1765.0                      29.0        16.0
# 43                         2061.0                      15.0        49.0
# 44                         2023.0                      16.0         7.0
# 45                          889.0                      41.0        11.0
# 46                         2151.0                      12.0        67.0
# 47                         3045.0                       3.0         8.0
# 48                         2187.0                      10.0        98.0
# 49                         6422.0                       1.0       216.0
# 50                            0.0                       0.0         0.0
# 51                            0.0                       0.0         0.0
# 52                            0.0                       0.0         0.0
# 53                            0.0                       0.0         0.0
#
#     Years to Inspect Each Workplace Once State or Federal Program
# 0                                  111.0                    State
# 1                                  173.0                  Federal
# 2                                  123.0                  Federal
# 3                                   82.0                    State
# 4                                  131.0                  Federal
# 5                                  137.0                  Federal
# 6                                  128.0                  Federal
# 7                                  175.0                  Federal
# 8                                   79.0                    State
# 9                                   98.0                    State
# 10                                 126.0                    State
# 11                                 238.0                  Federal
# 12                                  82.0                    State
# 13                                 118.0                  Federal
# 14                                  45.0                    State
# 15                                 104.0                    State
# 16                                  60.0                    State
# 17                                 119.0                  Federal
# 18                                 191.0                    State
# 19                                 125.0                  Federal
# 20                                 521.0                  Federal
# 21                                 184.0                  Federal
# 22                                  81.0                    State
# 23                                  80.0                  Federal
# 24                                 135.0                  Federal
# 25                                  68.0                    State
# 26                                 237.0                  Federal
# 27                                  49.0                    State
# 28                                 124.0                    State
# 29                                 108.0                    State
# 30                                  94.0                  Federal
# 31                                 107.0                  Federal
# 32                                  31.0                    State
# 33                                 122.0                  Federal
# 34                                 112.0                  Federal
# 35                                 101.0                    State
# 36                                  57.0                    State
# 37                                 110.0                  Federal
# 38                                 108.0                  Federal
# 39                                  50.0                    State
# 40                                 104.0                  Federal
# 41                                 112.0                  Federal
# 42                                 206.0                  Federal
# 43                                 138.0                  Federal
# 44                                 103.0                  Federal
# 45                                  58.0                    State
# 46                                 123.0                  Federal
# 47                                 111.0                  Federal
# 48                                 136.0                  Federal
# 49                                 179.0                    State
# 50                                   0.0                        0
# 51                                   0.0                        0
# 52                                   0.0                        0
# 53                                   0.0                        0

# %% [markdown]
# ## 3. Statistics Summary (a) (10 Points)
# Write a Python function named statistics_summary() that summarizes the "State	Number of Fatalities, 2012" distribution. The function include: mean, standard deviation, median,maximum number of fatalities, the index of the maximum number of fatalities, the state name of the maximum number of fatalities, and the histogram plot.

# %% [markdown]
# ## 4. Statistics Summary (b) (10 Points)
#
# By using for loop, show the statistics summary of "Number of Injuries/Illnesses 2012", "Penalties FY 2013", "Inspectors", and "Years to Inspect Each Workplace"

# %% [markdown]
# ## 5. Show the Pair Plot  (30 Points)
#
# Divide the data into two populations based on the "state number of Fatalities, 2012":
#
# one group with Fatalities >= 100, and
#
# the other with Fatalities < 100.
#
# Create the pair plots among all variables, and replace the diagonal plots with 1D histograms.
